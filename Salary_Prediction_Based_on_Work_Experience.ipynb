# %% [markdown]
# <a href="https://colab.research.google.com/github/Thrishasivasakthi/python/blob/main/Salary_Prediction_Based_on_Work_Experience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Dataset

# %%
dataset = pd.read_csv('/content/salary_data .csv')
print(dataset)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
X = dataset.iloc[:,:-1].values
Y = dataset.iloc[:,-1].values

print(X)
print(Y)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
plt.xlabel('expeerience')
plt.ylabel('salary')
plt.title('experience vs. salary')
plt.scatter(X,Y,color='red',marker='+')

# %% [markdown]
# # Split the data

# %%
 from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3)
print(X_train.shape, X_test.shape)
# Out:
# (21, 1) (9, 1)

# %% [markdown]
# # Fitting Simple Linear Regression

# %%
 from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predicting the test results

# %%
 Y_pred = model.predict(X_test)
print(Y_pred)
print(Y_train)
# Out:
# [ 48323.76238016 115733.99735831  73256.31504331  64022.03627918
#   64945.4641556   75103.17079614 124968.27612244  83414.02168386
#   64945.4641556 ]
# [ 46205. 122391.  37731.  64445. 105582. 112635.  91738.  98273.  39343.
#   81363.  83088.  43525. 109431. 101302.  54445.  56642.  60150.  57081.
#   61111. 113812.  57189.]

# %% [markdown]
# # Calculate Accuracy

# %%
 accuracy = model.score(X_test,Y_test)
print(accuracy)
# Out:
# 0.9305573931820401

# %% [markdown]
# # Plot the regression curve

# %%
plt.scatter(X_train,Y_train,color='red',marker='+')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('YearsExperience vs Salary (Traning Data) ')
plt.plot(X_train, model.predict(X_train), color='blue')
plt.show()

plt.scatter(X_test,Y_test,color='red',marker='+')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('YearsExperience vs Salary (Test DataSet)')
plt.plot(X_test, model.predict(X_test), color='blue')
plt.show()

# %% [markdown]
# # Predict on external data

# %%
test_data = np.array([[3300]])
test_pred = model.predict(test_data)
print(test_pred)
# Out:
# [30501128.27072898]

# %% [markdown]
# #Predict data from user through manual input

# %%
WorkExperience = int(input("How many years have you worked in this field of expertise?"))
SalaryEarned = model.predict(np.array([[WorkExperience]]))
print('Estimated salary ' + str(WorkExperience) + 'years of experience are' + str(SalaryEarned[0]))
# Out:
# How many years have you worked in this field of expertise?8
# Estimated salary 8years of experience are101882.57921211654
